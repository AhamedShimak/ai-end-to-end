# %%
# !pip install diffusers
# Out:
# Collecting diffusers
#   Downloading diffusers-0.16.1-py3-none-any.whl (934 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.9/934.9 kB 22.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.10/site-packages (from diffusers) (9.5.0)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from diffusers) (3.12.0)
# Collecting huggingface-hub>=0.13.2 (from diffusers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/local/python/3.10.4/lib/python3.10/site-packages (from diffusers) (6.6.0)
# Requirement already satisfied: numpy in /usr/local/python/3.10.4/lib/python3.10/site-packages (from diffusers) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from diffusers) (2023.5.5)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from diffusers) (2.28.2)
# Collecting fsspec (from huggingface-hub>=0.13.2->diffusers)
#   Downloading fsspec-2023.5.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 8.6 MB/s eta 0:00:00
# Collecting tqdm>=4.42.1 (from huggingface-hub>=0.13.2->diffusers)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers) (23.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->diffusers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->diffusers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->diffusers) (2022.12.7)
# Installing collected packages: tqdm, fsspec, huggingface-hub, diffusers
# Successfully installed diffusers-0.16.1 fsspec-2023.5.0 huggingface-hub-0.14.1 tqdm-4.65.0
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import requests
API_TOKEN="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"
API_URL = "https://api-inference.huggingface.co/models/runwayml/stable-diffusion-v1-5"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": "Astronaut riding a horse ",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
